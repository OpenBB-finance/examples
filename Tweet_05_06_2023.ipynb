# %%
import pandas as pd
from openbb_terminal.sdk import openbb

# %% [markdown]
# <h1>Tweet 05-06-2023</h1>
#
# Actively traded treasury securities determine the theoretical value of U.S treasury rates as obtained daily by the treasury institution.
#
# Called the Constant Maturity, this valuable metric is available on the #OpenBB SDK to aid your economic research.

# %%
openbb.forecast.plot(openbb.fixedincome.tmc(), columns = ['T10Y3M'])
