# %%
import pandas as pd
from openbb_terminal.sdk import openbb

# %% [markdown]
# <h1>Tweet 21-05-2023</h1>
#
# ETS (Error, trend & seasonality) is a forecasting technique that compares specific relationships between the named metrics to chart out predicted price movements.
#
# Check out how you can use this tool to transform your investment research!

# %%
openbb.forecast.autoets_chart(data = openbb.stocks.load('SPY'), target_column = 'Close')
# Out:
# Loading Daily data for SPY with starting period 2020-05-20.
# ...
# Forecast:   0%|          | 0/1 [00:00<?, ?it/s]
# AutoETS obtains MAPE: 1.20%
#    Actual price: 411.09
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Datetime   ┃ Prediction ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 2023-05-25 │ 411.09     │
# ├────────────┼────────────┤
# │ 2023-05-26 │ 411.09     │
# ├────────────┼────────────┤
# │ 2023-05-29 │ 411.09     │
# ├────────────┼────────────┤
# │ 2023-05-30 │ 411.09     │
# ├────────────┼────────────┤
# │ 2023-05-31 │ 411.09     │
# └────────────┴────────────┘
