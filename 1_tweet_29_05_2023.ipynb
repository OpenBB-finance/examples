# %%
import pandas as pd
from openbb_terminal.sdk import openbb

# %% [markdown]
# <h1>Tweet 29-05-2023</h1>
#
# Due diligence for crypto pairs has never been easier, thanks to the #OpenBB SDK. Get real-time OHLC data for any crypto trading pairs and stay ahead in your investment research.

# %%
from openbb_terminal.sdk import openbb
openbb.crypto.dd.candle(symbol="eth-usdt", interval="24hour")
# Out:
#            date     Open     High      Low    Close        Volume
# 0    1685059200  1805.87  1823.62  1796.66  1817.60   2357.168197
# 1    1684972800  1799.80  1818.11  1759.47  1805.72   9512.131969
# 2    1684886400  1854.30  1854.30  1775.28  1800.08   9040.304826
# 3    1684800000  1817.79  1873.66  1815.07  1854.23   8682.510480
# 4    1684713600  1804.38  1828.75  1791.84  1817.48   5919.754836
# ..          ...      ...      ...      ...      ...           ...
# 295  1659571200  1617.67  1662.69  1581.18  1608.39   8227.063559
# 296  1659484800  1633.86  1684.23  1590.40  1617.33  11533.861514
# 297  1659398400  1630.36  1678.16  1559.36  1630.78  13564.754346
# 298  1659312000  1676.88  1704.45  1606.24  1630.66   8568.326435
# 299  1659225600  1696.51  1754.83  1666.22  1677.63   6148.806990
#
# [300 rows x 6 columns]
