# %%
import pandas as pd
from openbb_terminal.sdk import openbb

# %% [markdown]
# <h1>Tweet 30-05-2023</h1>
#
# For a deep dive into the descriptive statistics of any particular stock price data, look no further than the #OpenBB SDK.
#
# In an instant, you can get the results of large statistical calculations, shaving hours off your research workflow!

# %%
openbb.forecast.desc(data = openbb.stocks.load('SPY'))
# Out:
# Loading Daily data for SPY with starting period 2020-05-20.
#              Open        High         Low       Close   Adj Close  \
# count  760.000000  760.000000  760.000000  760.000000  760.000000
# mean   390.505777  393.047482  387.712321  390.561283  390.561283
# std     42.775019   42.807057   42.754226   42.802674   42.802674
# min    281.387566  282.400127  280.097975  281.683716  281.683716
# 25%    367.431138  370.587792  364.334483  367.589424  367.589424
# 50%    397.746048  399.701707  394.797497  397.214035  397.214035
# 75%    421.151428  424.083532  417.823822  421.621513  421.621513
# max    469.776692  470.521726  466.678956  468.296387  468.296387
#
#              Volume   Dividends  Stock Splits
# count  7.600000e+02  760.000000         760.0
# mean   8.262646e+07    0.023455           0.0
# std    3.088523e+07    0.186182           0.0
# min    2.645790e+07    0.000000           0.0
# 25%    5.992000e+07    0.000000           0.0
# ...
