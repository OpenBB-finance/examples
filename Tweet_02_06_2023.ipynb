# %% [markdown]
# <h1>Tweet 02-06-2023</h1>
#
# Moody's AAA Corporate bond is a useful index of the performance of all AAA-rated bonds as issued by the ratings agency.
#
# With the #OpenBB SDK, get this and many other key pieces of the wonderful puzzle that is the economy.

# %%
import pandas as pd
from openbb_terminal.sdk import openbb

# %%
openbb.forecast.plot(openbb.fixedincome.moody(), columns = ['aaa_index'])
