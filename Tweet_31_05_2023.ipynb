# %%
import pandas as pd
from openbb_terminal.sdk import openbb

# %% [markdown]
# <h1>Tweet 31-05-2023</h1>
#
# By accounting for seasonal changes, the seasonal naive forecast model can sometimes be very helpful in predicting price changes.
#
# Get this and many more on the #OpenBB SDK.

# %%
openbb.forecast.seasonalnaive_chart(data = openbb.stocks.load("AAPL"), target_column = "Close")
# Out:
# Loading Daily data for AAPL with starting period 2020-05-21.
# ...
# Forecast:   0%|          | 0/1 [00:00<?, ?it/s]
# SeasonalNaive obtains MAPE: 3.25%
#    Actual price: 174.42
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Datetime   ┃ Prediction ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 2023-05-29 │ 175.05     │
# ├────────────┼────────────┤
# │ 2023-05-30 │ 175.16     │
# ├────────────┼────────────┤
# │ 2023-05-31 │ 174.20     │
# ├────────────┼────────────┤
# │ 2023-06-01 │ 171.56     │
# ├────────────┼────────────┤
# │ 2023-06-02 │ 171.84     │
# └────────────┴────────────┘
